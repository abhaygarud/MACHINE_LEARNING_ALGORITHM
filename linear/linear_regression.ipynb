# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#creating a dataframe in pandas 
df=pd.read_csv("homeprices.csv")
df
# Out:
#    area  prices
# 0  2600  550000
# 1  3000  600000
# 2  3200  700000
# 3  3600  720000
# 4  4000  780000
# 5  5000  800000

# %%
plt.scatter(df.area,df.prices,color="r",marker="+",label="area")

plt.xlabel("area")
plt.ylabel("prices")
plt.title("home price")
plt.legend()

# %%
#creating linear regression sklearn imported module
reg=linear_model.LinearRegression()
#to train data
reg.fit(df[['area']],df.prices)
# Out:
# LinearRegression()

# %%
reg.predict([[3000]])
# Out:
# array([632348.62385321])

# %% [raw]
# reg.ioc

# %%
reg.coef_
# Out:
# array([104.67889908])

# %%
reg.intercept_
# Out:
# 318311.92660550453

# %%
#y=mx+c
104.67889908*3000+318311.92660550453
# Out:
# 632348.6238455046

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("prices")
plt.title("home price")
plt.scatter(df.area,df.prices,color="r",marker="+",label="area")
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
plt.show()

# %%
d=pd.read_csv("area.csv")
d
#reading csv file to make la machine learning to make prediction on price with the help of area
# Out:
#     area
# 0   2000
# 1   2300
# 2   2333
# 3   2100
# 4   3456
# 5   3200
# 6   3800
# 7   7000
# 8   5000
# 9   4000
# 10  4500
# 11  4800
# 12  2900

# %%
p=reg.predict(d)
d['prices']=p
d
# Out:
#     area        prices
# 0   2000  5.276697e+05
# 1   2300  5.590734e+05
# 2   2333  5.625278e+05
# 3   2100  5.381376e+05
# 4   3456  6.800822e+05
# 5   3200  6.532844e+05
# 6   3800  7.160917e+05
# 7   7000  1.051064e+06
# 8   5000  8.417064e+05
# 9   4000  7.370275e+05
# 10  4500  7.893670e+05
# 11  4800  8.207706e+05
# 12  2900  6.218807e+05
